# %% [markdown]
# # 05 · Realized vs Implied Vol — Vol Risk Premium
# Volatility Surface Series · COMPLETE | Niraj Neupane | github.com/nirajneupane17

# %%
import pandas as pd
vts = pd.read_csv("../data/vol_timeseries.csv", parse_dates=["date"])
print(f"Period: {vts.date.min().date()} to {vts.date.max().date()}")
print(f"Vol Risk Premium Mean: {vts.vol_risk_premium.mean():.2f}%")
print(f"IV > RV: {(vts.vol_risk_premium>0).mean()*100:.1f}% of observations")
print(f"Max VIX-proxy: {vts.vix_proxy.max():.1f}% (COVID)")
print(f"Min VIX-proxy: {vts.vix_proxy.min():.1f}%")

# %%
import matplotlib.pyplot as plt
img=plt.imread("../results/06_realized_vs_implied.png")
fig,ax=plt.subplots(figsize=(15,10)); ax.imshow(img); ax.axis("off"); plt.show()
print("Volatility Surface project complete.")
