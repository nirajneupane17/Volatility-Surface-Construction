# %% [markdown]
# # 03 · Surface Heatmap & Contour
# **Volatility Surface Construction**
# IV surface visualisation, regime identification, arbitrage detection.
#
# Author: Niraj Neupane | github.com/nirajneupane17

# %%
import sys; sys.path.insert(0,"../src")
import numpy as np, pandas as pd, matplotlib.pyplot as plt
from surface_analytics import vol_skew, vol_risk_reversal, vol_butterfly
print("OK")

# %%
opts=pd.read_csv("../data/options_chain.csv")
for exp in ["7D","30D","90D","365D"]:
    sk=vol_skew(opts,exp)*100
    rr=vol_risk_reversal(opts,exp)*100
    bf=vol_butterfly(opts,exp)*100
    print(f"{exp}: skew={sk:.2f}%  RR={rr:.2f}%  butterfly={bf:.2f}%")

# %%
img=plt.imread("../results/03_surface_heatmap.png")
fig,ax=plt.subplots(figsize=(15,6)); ax.imshow(img); ax.axis("off"); plt.show()
