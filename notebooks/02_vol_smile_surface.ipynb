# %% [markdown]
# # 02 · Volatility Smile & 3D Surface
# Volatility Surface Series | Niraj Neupane | github.com/nirajneupane17

# %%
import sys; sys.path.insert(0,"../src")
import pandas as pd
from vol_surface import vol_smile, atm_term_structure
print("OK")

# %%
surf = pd.read_csv("../data/vol_surface.csv")
smile = vol_smile(surf, 30)
print(f"30-day smile - {len(smile)} strikes")
print(smile[["strike_pct","implied_vol_pct","delta"]].to_string())

# %%
import matplotlib.pyplot as plt
img=plt.imread("../results/03_vol_surface_3d.png")
fig,ax=plt.subplots(figsize=(18,8)); ax.imshow(img); ax.axis("off"); plt.show()
