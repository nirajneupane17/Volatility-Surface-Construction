# %% [markdown]
# # 05 · Greeks Surface & Term Structure
# **Volatility Surface Construction**
# Delta, Gamma, Vega, Theta across the full surface. ATM IV term structure and forward vol.
#
# Author: Niraj Neupane | github.com/nirajneupane17

# %%
import sys; sys.path.insert(0,"../src")
import numpy as np, pandas as pd, matplotlib.pyplot as plt
from bs_engine import bs_delta, bs_gamma, bs_vega, bs_theta
from surface_analytics import atm_term_structure, forward_vol
S0=450; r=0.053; q=0.013
print("OK")

# %%
opts=pd.read_csv("../data/options_chain.csv")
term=pd.read_csv("../data/term_structure.csv")
fwd=forward_vol(term)
print("ATM Term Structure:")
print(fwd[["expiry","T","implied_vol","forward_vol"]].to_string(index=False))

# %%
img=plt.imread("../results/04_term_structure.png")
fig,ax=plt.subplots(figsize=(15,6)); ax.imshow(img); ax.axis("off"); plt.show()

# %%
img=plt.imread("../results/06_greeks_surface.png")
fig,ax=plt.subplots(figsize=(15,10)); ax.imshow(img); ax.axis("off"); plt.show()
