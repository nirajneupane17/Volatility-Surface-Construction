# %% [markdown]
# # 04 · Heston Model Calibration
# Volatility Surface Series | Niraj Neupane | github.com/nirajneupane17

# %%
import sys; sys.path.insert(0,"../src")
import pandas as pd
from heston_model import calibrate_heston, heston_iv_approx
print("OK")

# %%
surf = pd.read_csv("../data/vol_surface.csv")
sample = surf[surf["maturity_days"].isin([30,90,180,360])].copy()
result = calibrate_heston(sample, S=185, r=0.053)
print("Heston Calibrated Parameters:")
for k,v in result.items(): print(f"  {k}: {v}")

# %%
import matplotlib.pyplot as plt
img=plt.imread("../results/05_heston_calibration.png")
fig,ax=plt.subplots(figsize=(18,6)); ax.imshow(img); ax.axis("off"); plt.show()
